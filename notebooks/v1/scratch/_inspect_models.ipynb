# %%
# %matplotlib inline
import sklearn
from tqdm import tqdm
import sed_eval
import os
import milsed
import pumpp
import numpy as np
import jams
import json
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pumpp
import scipy
# Out:
# Using TensorFlow backend.

# %%
OUTPUT_PATH = '/home/js7561/dev/milsed/models/resources/'
pump = pickle.load(open(os.path.join(OUTPUT_PATH, 'pump.pkl'), 'rb'))

# %%
cbhg, inputs, outputs = milsed.models.MODELS['cbhg_smp'](pump, 1.0)

# %%
cbhg.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# mel/mag (InputLayer)             (None, None, 128, 1)  0
# ____________________________________________________________________________________________________
# squeeze_layer_2 (SqueezeLayer)   (None, None, 128)     0           mel/mag[0][0]
# ____________________________________________________________________________________________________
# conv1d_19 (Conv1D)               (None, None, 128)     16512       squeeze_layer_2[0][0]
# ____________________________________________________________________________________________________
# conv1d_20 (Conv1D)               (None, None, 128)     32896       squeeze_layer_2[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
crnn2d, ins, outs = milsed.models.MODELS['crnn2d_smp'](pump, 1.0)

# %%
crnn2d.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# mel/mag (InputLayer)         (None, None, 128, 1)      0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, None, 128, 1)      4
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, 128, 64)     640
# _________________________________________________________________
# batch_normalization_6 (Batch (None, None, 128, 64)     256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, 128, 128)    73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, None, 128, 128)    512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, 1, 256)      4194560
# ...

# %%
crnn2d2, ins, outs = milsed.models.MODELS['crnn2d2_smp'](pump, 1.0)

# %%
crnn2d2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# mel/mag (InputLayer)         (None, None, 128, 1)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 128, 1)      4
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, 128, 64)     640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 128, 64)     256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, None, 64, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, 64, 128)     73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 64, 128)     512
# ...

# %%
crnn2d2.input_shape
# Out:
# (None, None, 128, 1)

# %%
pumpfolder = '/beegfs/js7561/datasets/dcase2017/task4_official/combined/features_silence/'
fid = "Y-3exNVlj92w_30.000_40.000"

# Load test data
pumpfile = os.path.join(pumpfolder, fid + '.h5')
dpump = milsed.utils.load_h5(pumpfile)
datum = dpump['mel/mag']
ytrue = dpump['static/tags'][0]

# %%
datum.shape
# Out:
# (1, 430, 128, 1)

# %%
crnnL3_11_smp, ins, outs = milsed.models.MODELS['crnnL3_11_smp'](pump, 1.0)

# %%
crnnL3_11_smp.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# mel/mag (InputLayer)         (None, None, 128, 1)      0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 128, 1)      4
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, 128, 16)     160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, None, 128, 16)     64
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, 128, 16)     2320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, None, 128, 16)     64
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, 128, 16)     2320
# ...

# %%
crnnL3_12_smp, ins, outs = milsed.models.MODELS['crnnL3_12_smp'](pump, 1.0)

# %%
crnnL3_12_smp.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# mel/mag (InputLayer)             (None, None, 128, 1)  0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, None, 128, 1)  4           mel/mag[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, None, 128, 16) 160         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, None, 128, 16) 64          conv2d_1[0][0]
# ____________________________________________________________________________________________________
# ...
